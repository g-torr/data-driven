# %%
from pylab import *
import scipy
import ruptures as rpt
# %matplotlib inline

# %%
import mat2python
data,trial,classes=mat2python.mat2python(repetition_number=0)
#sampling rate 10 Hz
# Out:
#  I am loading the 0 repetition of the protocol

# %% [markdown]
# Consider only oxy data, discard the others

# %%
oxy=data[:,0:52]
plot(oxy)#oxy
figure()
'''plot(data[:,52:104])#deoxy
figure()
plot(data[:,104:156])#oxy+#deoxy'''
print(shape(oxy))
# Out:
# (2671, 52)

# %% [markdown]
# Protocol consists of 12 seconds of computation, followed by 28 s of rest. Intially there are 24 s of rest before starting.

# %%
# %matplotlib 
plot(oxy)#oxy
vlines(trial,-1,1,linestyles="--")
diff(trial)
# Out:
# Using matplotlib backend: Qt5Agg
# array([122, 279, 121, 279, 121, 279, 121, 279, 121, 279, 121], dtype=uint32)

# %%
roi1=[46,47,48]
roi2=[18,28,29]
roi3=[13, 23, 24]
plot(oxy[:,roi1],label="ROI1")
vlines(trial,-0.5,1,linestyles="--")
figure()
vlines(trial,-0.4,0.8,linestyles="--")
plot(oxy[:,roi2],label="ROI2")
figure()
vlines(trial,-0.25,0.5,linestyles="--")
plot(oxy[:,roi3],label="ROI3")
#legend()
# Out:
# [<matplotlib.lines.Line2D at 0x7fd9e810a080>,
#  <matplotlib.lines.Line2D at 0x7fd9e80db128>,
#  <matplotlib.lines.Line2D at 0x7fd9e80db320>]

# %%
# detection
algo = rpt.Pelt(model="rbf").fit(oxy[:,1])
result = algo.predict(pen=10)

# %%
print(len(result))
# Out:
# 25

# %%
len(algo.predict(20))
# Out:
# 15

# %%
shape(scipy.io.loadmat("data1.mat")["dati"][0,0][0])
# Out:
# (2671, 156)

# %%
scipy.io.loadmat("data1.mat")["dati"][0,0][4]
# Out:
# array([[array(['mental arithmetic'],
#       dtype='<U17'),
#         array(['rest'],
#       dtype='<U4')]], dtype=object)

# %%
repetition_number=0; #the experiment is repeated 3 times, repetition_number can take values 0,1,2
oxy,fs,trial,y,classes=scipy.io.loadmat("S01.mat")["data"][repetition_number][0][0,0]

# %%
classes
# Out:
# array([[array(['mental arithmetic'],
#       dtype='<U17'),
#         array(['rest'],
#       dtype='<U4')]], dtype=object)

# %%
import mat2python
oxy,trial,classes=mat2python.mat2python()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-21-4ddc29ee01c5> in <module>()
#       1 import mat2python
# ----> 2 oxy,trial,classes=mat2python.mat2python()
#
# AttributeError: module 'mat2python' has no attribute 'mat2python'

# %%
from scipy import io
def mat2python(repetition_number=0):
	'''This function read the SO1.mat file. The experiment is repeated 3 times, repetition_number can take values 0,1,2'''
	print(" I am loading the "+str(repetition_number)+" repetition of the protocol")
	oxy,fs,trial,y,classes=scipy.io.loadmat("S01.mat")["data"][repetition_number][0][0,0]
	return oxy,trial,classes

# %%
mat2python(0)
# Out:
#  I am loading the 0 repetition of the protocol
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~/Documents/data-driven/mat2python.py in <module>()
# ----> 1 mat2python(0)
#
# ~/Documents/data-driven/mat2python.py in mat2python(repetition_number)
#       3         '''This function read the SO1.mat file. The experiment is repeated 3 times, repetition_number can take values 0,1,2'''
#       4         print(" I am loading the "+str(repetition_number)+" repetition of the protocol")
# ----> 5         oxy,fs,trial,y,classes=scipy.io.loadmat("S01.mat")["data"][repetition_number][0][0,0]
#       6         return oxy,trial,classes
#
# NameError: name 'scipy' is not defined

# %%
run -i mat2python
# Out:
#  I am loading the 0 repetition of the protocol
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~/Documents/data-driven/mat2python.py in <module>()
#       3 '''This function read the SO1.mat file. The experiment is repeated 3 times, repetition_number can take values 0,1,2'''
#       4 print(" I am loading the "+str(repetition_number)+" repetition of the protocol")
# ----> 5 oxy,fs,trial,y,classes=scipy.io.loadmat("S01.mat")["data"][repetition_number][0][0,0]
#       6 #return oxy,trial,classes
#
# NameError: name 'scipy' is not defined
